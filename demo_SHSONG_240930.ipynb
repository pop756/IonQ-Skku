# %%
from TBM_ver4_all_backend import TightBindingModel_Hamiltonian, TightBindingModel_VQE
import warnings

warnings.filterwarnings('ignore')

# %%
#######################
# 1-D monatomic chain #
#######################

num_q_orbital=2
num_q_site=5

t_0=[[0,3],
    [3,0]]
t_1=[[0, 0],
    [3, 0]]

obj_hamiltonian=TightBindingModel_Hamiltonian(
    num_q_orbital=num_q_orbital,
    num_q_site=num_q_site,
    t_0=t_0,
    t_1=t_1
)
hamiltonian_dictionary=obj_hamiltonian.Hamiltonian()

obj_vqe=TightBindingModel_VQE(
    num_q_orbital=num_q_orbital,
    num_q_site=num_q_site,
    dimension=1,
    hamiltonian_dictionary=hamiltonian_dictionary,
    simulation_mode='noisy' 
)

obj_vqe.Energy_Momentum_Dispersion_1D(upper_bound_level=1)
# Out:
# 0th eigen energy information (p=0) : {   'fun': -5.898381471633911,
#     'jac': None,
#     'nfev': 36,
#     'nit': None,
#     'njev': None,
#     'x': array([0.77581933, 3.17914093])}
# 0th eigen energy information (p=1) : {   'fun': -1.4466848373413086,
#     'jac': None,
#     'nfev': 37,
#     'nit': None,
#     'njev': None,
#     'x': array([0.77306978, 3.01208463])}
# 0th eigen energy information (p=2) : {   'fun': -3.678911715745926,
#     'jac': None,
#     'nfev': 37,
#     'nit': None,
#     'njev': None,
#     'x': array([0.8005216 , 3.03154896])}
# 0th eigen energy information (p=3) : {   'fun': -1.9916545450687408,
#     'jac': None,
#     'nfev': 35,
#     'nit': None,
#     'njev': None,
#     'x': array([-0.78568062,  0.54817076])}
# 0th eigen energy information (p=4) : {   'fun': -4.798068344593048,
#     'jac': None,
#     'nfev': 40,
#     'nit': None,
#     'njev': None,
#     'x': array([0.7724209 , 3.19669008])}
# ...

# %%
#######################
# 1-D diatomic chain #
#######################

num_q_orbital=2
num_q_site=5

t_0=[[-0.5,1],
    [1,0.5]]
t_1=[[0, 1],
    [0, 0]]

obj_hamiltonian=TightBindingModel_Hamiltonian(
    num_q_orbital=num_q_orbital,
    num_q_site=num_q_site,
    t_0=t_0,
    t_1=t_1
)
hamiltonian_dictionary=obj_hamiltonian.Hamiltonian()

obj_vqe=TightBindingModel_VQE(
    num_q_orbital=num_q_orbital,
    num_q_site=num_q_site,
    dimension=1,
    hamiltonian_dictionary=hamiltonian_dictionary,
    simulation_mode='noisy' 
)

obj_vqe.Energy_Momentum_Dispersion_1D(upper_bound_level=1)
# Out:
# 0th eigen energy information (p=0) : {   'fun': -2.024165689945221,
#     'jac': None,
#     'nfev': 34,
#     'nit': None,
#     'njev': None,
#     'x': array([0.89793064, 3.15796886])}
# 0th eigen energy information (p=1) : {   'fun': -0.6018929854035378,
#     'jac': None,
#     'nfev': 32,
#     'nit': None,
#     'njev': None,
#     'x': array([1.99520871, 0.87458959])}
# 0th eigen energy information (p=2) : {   'fun': -1.3080136328935623,
#     'jac': None,
#     'nfev': 36,
#     'nit': None,
#     'njev': None,
#     'x': array([0.95588798, 3.06847033])}
# 0th eigen energy information (p=3) : {   'fun': -0.5441008731722832,
#     'jac': None,
#     'nfev': 30,
#     'nit': None,
#     'njev': None,
#     'x': array([1.38880861, 1.44918462])}
# 0th eigen energy information (p=4) : {   'fun': -1.6497783660888672,
#     'jac': None,
#     'nfev': 29,
#     'nit': None,
#     'njev': None,
#     'x': array([0.87480505, 3.15713427])}
# ...

# %%
print(

# %%
###########################
# 2-D monatomic hexagonal #
###########################

num_q_orbital=2
num_q_site=5

t_0=[[0,1],
    [1,0]]
t_1=[[0,1],
    [1,0]]

obj_hamiltonian=TightBindingModel_Hamiltonian(
    num_q_orbital=num_q_orbital,
    num_q_site=num_q_site,
    t_0=t_0,
    t_1=t_1
)
hamiltonian_dictionary=obj_hamiltonian.Hamiltonian()

obj_vqe=TightBindingModel_VQE(
    num_q_orbital=num_q_orbital,
    num_q_site=num_q_site,
    dimension=1,
    hamiltonian_dictionary=hamiltonian_dictionary,
    simulation_mode='noisy' 
)

obj_vqe.Energy_Momentum_Dispersion_1D(upper_bound_level=1)
# Out:
# 0th eigen energy information (p=0) : {   'fun': -2.9603848457336426,
#     'jac': None,
#     'nfev': 38,
#     'nit': None,
#     'njev': None,
#     'x': array([0.81167672, 3.17059569])}
# 0th eigen energy information (p=1) : {   'fun': -0.031081825494766235,
#     'jac': None,
#     'nfev': 28,
#     'nit': None,
#     'njev': None,
#     'x': array([0.80265191, 0.18043557])}
# 0th eigen energy information (p=2) : {   'fun': -1.4569780230522156,
#     'jac': None,
#     'nfev': 38,
#     'nit': None,
#     'njev': None,
#     'x': array([0.79603262, 3.15243081])}
# 0th eigen energy information (p=3) : {   'fun': -0.06742823123931885,
#     'jac': None,
#     'nfev': 35,
#     'nit': None,
#     'njev': None,
#     'x': array([0.81773875, 3.06386171])}
# 0th eigen energy information (p=4) : {   'fun': -2.229531481862068,
#     'jac': None,
#     'nfev': 36,
#     'nit': None,
#     'njev': None,
#     'x': array([0.80019192, 3.14117465])}
# ...

# %%
print(
# Out:
#   Cell In[3], line 1
#     print(
#           ^
# SyntaxError: incomplete input

# %%
from TBM_ver4 import TightBindingModel_Hamiltonian, TightBindingModel_VQE
import warnings

warnings.filterwarnings('ignore')

# %%
###########################
# 2-D monatomic hexagonal #
###########################

num_q_orbital=2
num_q_site=5

t_0=[[0,1],
    [1,0]]
t_1=[[0,1],
    [1,0]]

obj_hamiltonian=TightBindingModel_Hamiltonian(
    num_q_orbital=num_q_orbital,
    num_q_site=num_q_site,
    t_0=t_0,
    t_1=t_1
)
hamiltonian_dictionary=obj_hamiltonian.Hamiltonian()

obj_vqe=TightBindingModel_VQE(
    num_q_orbital=num_q_orbital,
    num_q_site=num_q_site,
    dimension=1,
    hamiltonian_dictionary=hamiltonian_dictionary,
    simulation_mode='noisy'
)

obj_vqe.Energy_Momentum_Dispersion_1D(upper_bound_level=1)
# Out:
# 0th eigen energy information (p=0) : {   'fun': -2.9560546874999982,
#     'jac': None,
#     'nfev': 39,
#     'nit': None,
#     'njev': None,
#     'x': array([0.79190184, 3.14350552])}
# 0th eigen energy information (p=1) : {   'fun': -2.917465139856949,
#     'jac': None,
#     'nfev': 50,
#     'nit': None,
#     'njev': None,
#     'x': array([0.78436521, 3.1358808 ])}
# 0th eigen energy information (p=2) : {   'fun': -2.7928340244618344,
#     'jac': None,
#     'nfev': 38,
#     'nit': None,
#     'njev': None,
#     'x': array([0.81029778, 3.15867838])}
# 0th eigen energy information (p=3) : {   'fun': -2.627181984040324,
#     'jac': None,
#     'nfev': 45,
#     'nit': None,
#     'njev': None,
#     'x': array([0.80938661, 3.14132191])}
# 0th eigen energy information (p=4) : {   'fun': -2.372955029813007,
#     'jac': None,
#     'nfev': 36,
#     'nit': None,
#     'njev': None,
#     'x': array([0.80372904, 3.10432076])}
# ...

# %%
print(

# %%
######################
# 1-D monatomic chain #
######################

num_q_orbital=2
num_q_site=5

t_0=[[0,3],
    [3,0]]
t_1=[[0, 0],
    [3, 0]]

obj_hamiltonian=TightBindingModel_Hamiltonian(
    num_q_orbital=num_q_orbital,
    num_q_site=num_q_site,
    t_0=t_0,
    t_1=t_1
)
hamiltonian_dictionary=obj_hamiltonian.Hamiltonian()

obj_vqe=TightBindingModel_VQE(
    num_q_orbital=num_q_orbital,
    num_q_site=num_q_site,
    dimension=1,
    hamiltonian_dictionary=hamiltonian_dictionary,
    simulation_mode='noisy'
)

obj_vqe.Energy_Momentum_Dispersion_1D(upper_bound_level=1)
# Out:
# 0th eigen energy information (p=0) : {   'fun': -5.888671874999998,
#     'jac': None,
#     'nfev': 40,
#     'nit': None,
#     'njev': None,
#     'x': array([0.75690124, 3.15934014])}
# 0th eigen energy information (p=1) : {   'fun': -5.865466261619488,
#     'jac': None,
#     'nfev': 40,
#     'nit': None,
#     'njev': None,
#     'x': array([-0.79293902,  0.00834101])}
# 0th eigen energy information (p=2) : {   'fun': -5.794547761613258,
#     'jac': None,
#     'nfev': 35,
#     'nit': None,
#     'njev': None,
#     'x': array([-0.79505892,  0.22679602])}
# 0th eigen energy information (p=3) : {   'fun': -5.417107688438691,
#     'jac': None,
#     'nfev': 35,
#     'nit': None,
#     'njev': None,
#     'x': array([-0.74430698,  0.57900668])}
# 0th eigen energy information (p=4) : {   'fun': -5.365927054641207,
#     'jac': None,
#     'nfev': 32,
#     'nit': None,
#     'njev': None,
#     'x': array([-0.79103435,  0.30124864])}
# ...

# %%
print(

# %%
######################
# 1-D diatomic chain #
######################

num_q_orbital=2
num_q_site=5

t_0=[[-0.5,1],
    [1,0.5]]
t_1=[[0, 1],
    [0, 0]]

obj_hamiltonian=TightBindingModel_Hamiltonian(
    num_q_orbital=num_q_orbital,
    num_q_site=num_q_site,
    t_0=t_0,
    t_1=t_1
)
hamiltonian_dictionary=obj_hamiltonian.Hamiltonian()

obj_vqe=TightBindingModel_VQE(
    num_q_orbital=num_q_orbital,
    num_q_site=num_q_site,
    dimension=1,
    hamiltonian_dictionary=hamiltonian_dictionary,
    simulation_mode='noisy'
)

obj_vqe.Energy_Momentum_Dispersion_1D(upper_bound_level=1)
# Out:
# 0th eigen energy information (p=0) : {   'fun': -2.015258789062499,
#     'jac': None,
#     'nfev': 32,
#     'nit': None,
#     'njev': None,
#     'x': array([0.88997176, 3.14078728])}
# 0th eigen energy information (p=1) : {   'fun': -2.005648501195013,
#     'jac': None,
#     'nfev': 32,
#     'nit': None,
#     'njev': None,
#     'x': array([0.90219837, 3.00245806])}
# 0th eigen energy information (p=2) : {   'fun': -1.9848767582389588,
#     'jac': None,
#     'nfev': 30,
#     'nit': None,
#     'njev': None,
#     'x': array([0.93306538, 3.02745037])}
# 0th eigen energy information (p=3) : {   'fun': -1.93857557451261,
#     'jac': None,
#     'nfev': 34,
#     'nit': None,
#     'njev': None,
#     'x': array([0.91406001, 2.74675514])}
# 0th eigen energy information (p=4) : {   'fun': -1.8804783929501356,
#     'jac': None,
#     'nfev': 35,
#     'nit': None,
#     'njev': None,
#     'x': array([0.96553003, 2.6933239 ])}
# ...
