# %%
from TBM import TightBindingModel_Hamiltonian, TightBindingModel_VQE

# %%
#########################
# Initialize conditions #
#########################

num_q_orbital=2
num_q_site=5
t_0=[[-0.5,1],
    [1,0.5]]
t_1=[[0, 1],
    [0, 0]]

# %%
obj_hamiltonian=TightBindingModel_Hamiltonian(
    num_q_orbital=num_q_orbital,
    num_q_site=num_q_site,
    t_0=t_0,
    t_1=t_1
)
hamiltonian=obj_hamiltonian.Hamiltonian()

obj_vqe=TightBindingModel_VQE(
    num_q_orbital=num_q_orbital,
    num_q_site=num_q_site,
    hamiltonian=hamiltonian
)

# %%
obj_vqe.Energy_Momentum_Dispersion(upper_bound_level=1)
# Out:
# 0th eigen energy information (p=0) : {   'fun': 0.2500000015852074,
#     'jac': None,
#     'nfev': 51,
#     'nit': None,
#     'njev': None,
#     'x': array([0.78543551, 3.14150837])}
# 0th eigen energy information (p=1) : {   'fun': 0.24039264501047308,
#     'jac': None,
#     'nfev': 42,
#     'nit': None,
#     'njev': None,
#     'x': array([-0.78532642,  0.19621582])}
# 0th eigen energy information (p=2) : {   'fun': 0.21193976875174023,
#     'jac': None,
#     'nfev': 40,
#     'nit': None,
#     'njev': None,
#     'x': array([-0.78546836,  0.39268306])}
# 0th eigen energy information (p=3) : {   'fun': 0.16573480801399426,
#     'jac': None,
#     'nfev': 36,
#     'nit': None,
#     'njev': None,
#     'x': array([-0.78545872,  0.58906389])}
# 0th eigen energy information (p=4) : {   'fun': 0.10355339576351597,
#     'jac': None,
#     'nfev': 46,
#     'nit': None,
#     'njev': None,
#     'x': array([-0.78529808,  0.78536222])}
# 0th eigen energy information (p=5) : {   'fun': 0.027785122406114277,
#     'jac': None,
#     'nfev': 46,
#     'nit': None,
#     'njev': None,
#     'x': array([-0.78529325,  0.98169165])}
# 0th eigen energy information (p=6) : {   'fun': -0.058658282920458854,
#     'jac': None,
#     'nfev': 45,
#     'nit': None,
#     'njev': None,
#     'x': array([-2.3562359 , -1.96347764])}
# 0th eigen energy information (p=7) : {   'fun': -0.15245483022449316,
#     'jac': None,
#     'nfev': 43,
#     'nit': None,
#     'njev': None,
#     'x': array([-0.78526844,  1.3743936 ])}
# 0th eigen energy information (p=8) : {   'fun': -0.24999999117937668,
#     'jac': None,
#     'nfev': 44,
#     'nit': None,
#     'njev': None,
#     'x': array([ 0.7855249, -1.5708758])}
# 0th eigen energy information (p=9) : {   'fun': -0.3475451565301972,
#     'jac': None,
#     'nfev': 40,
#     'nit': None,
#     'njev': None,
#     'x': array([ 0.78530365, -1.37443734])}
# 0th eigen energy information (p=10) : {   'fun': -0.44134171440718417,
#     'jac': None,
#     'nfev': 47,
#     'nit': None,
#     'njev': None,
#     'x': array([ 0.78545749, -1.17808617])}
# 0th eigen energy information (p=11) : {   'fun': -0.5277851150343645,
#     'jac': None,
#     'nfev': 35,
#     'nit': None,
#     'njev': None,
#     'x': array([ 0.78543326, -0.98183063])}
# 0th eigen energy information (p=12) : {   'fun': -0.6035533897047672,
#     'jac': None,
#     'nfev': 47,
#     'nit': None,
#     'njev': None,
#     'x': array([ 0.78543842, -0.78537315])}
# 0th eigen energy information (p=13) : {   'fun': -0.6657348037443913,
#     'jac': None,
#     'nfev': 40,
#     'nit': None,
#     'njev': None,
#     'x': array([ 0.78546404, -0.58909219])}
# 0th eigen energy information (p=14) : {   'fun': -0.7119397647909569,
#     'jac': None,
#     'nfev': 43,
#     'nit': None,
#     'njev': None,
#     'x': array([ 0.78535103, -0.39264587])}
# 0th eigen energy information (p=15) : {   'fun': -0.7403926372259033,
#     'jac': None,
#     'nfev': 40,
#     'nit': None,
#     'njev': None,
#     'x': array([ 0.78545703, -0.19624983])}
# 0th eigen energy information (p=16) : {   'fun': -0.7499999977779945,
#     'jac': None,
#     'nfev': 40,
#     'nit': None,
#     'njev': None,
#     'x': array([7.85347918e-01, 8.76230029e-05])}
# 0th eigen energy information (p=17) : {   'fun': -0.74039263853414,
#     'jac': None,
#     'nfev': 44,
#     'nit': None,
#     'njev': None,
#     'x': array([0.78536532, 0.19644454])}
# 0th eigen energy information (p=18) : {   'fun': -0.7119397615743708,
#     'jac': None,
#     'nfev': 37,
#     'nit': None,
#     'njev': None,
#     'x': array([0.78530227, 0.39267318])}
# 0th eigen energy information (p=19) : {   'fun': -0.6657348004615063,
#     'jac': None,
#     'nfev': 44,
#     'nit': None,
#     'njev': None,
#     'x': array([0.7855042 , 0.58907191])}
# 0th eigen energy information (p=20) : {   'fun': -0.6035533881933347,
#     'jac': None,
#     'nfev': 46,
#     'nit': None,
#     'njev': None,
#     'x': array([0.78542763, 0.78552357])}
# 0th eigen energy information (p=21) : {   'fun': -0.527785113356938,
#     'jac': None,
#     'nfev': 49,
#     'nit': None,
#     'njev': None,
#     'x': array([0.7853312 , 0.98183307])}
# 0th eigen energy information (p=22) : {   'fun': -0.44134170769992354,
#     'jac': None,
#     'nfev': 43,
#     'nit': None,
#     'njev': None,
#     'x': array([0.78552431, 1.17803239])}
# 0th eigen energy information (p=23) : {   'fun': -0.34754515901282634,
#     'jac': None,
#     'nfev': 44,
#     'nit': None,
#     'njev': None,
#     'x': array([0.78534095, 1.37450034])}
# 0th eigen energy information (p=24) : {   'fun': -0.24999999432658454,
#     'jac': None,
#     'nfev': 43,
#     'nit': None,
#     'njev': None,
#     'x': array([0.78544918, 1.5706093 ])}
# 0th eigen energy information (p=25) : {   'fun': -0.1524548369575237,
#     'jac': None,
#     'nfev': 43,
#     'nit': None,
#     'njev': None,
#     'x': array([0.78533455, 1.76715524])}
# 0th eigen energy information (p=26) : {   'fun': -0.05865827718211336,
#     'jac': None,
#     'nfev': 43,
#     'nit': None,
#     'njev': None,
#     'x': array([0.78551273, 1.96347125])}
# 0th eigen energy information (p=27) : {   'fun': 0.027785119303876907,
#     'jac': None,
#     'nfev': 49,
#     'nit': None,
#     'njev': None,
#     'x': array([0.78532514, 2.15987695])}
# 0th eigen energy information (p=28) : {   'fun': 0.10355339759586862,
#     'jac': None,
#     'nfev': 47,
#     'nit': None,
#     'njev': None,
#     'x': array([0.7855165 , 2.35619217])}
# 0th eigen energy information (p=29) : {   'fun': 0.16573480895910842,
#     'jac': None,
#     'nfev': 43,
#     'nit': None,
#     'njev': None,
#     'x': array([0.78546712, 2.55260269])}
# 0th eigen energy information (p=30) : {   'fun': 0.21193976770944717,
#     'jac': None,
#     'nfev': 53,
#     'nit': None,
#     'njev': None,
#     'x': array([0.78541707, 2.74879257])}
# 0th eigen energy information (p=31) : {   'fun': 0.24039264098066312,
#     'jac': None,
#     'nfev': 50,
#     'nit': None,
#     'njev': None,
#     'x': array([0.78541818, 2.94517508])}
# 1th eigen energy information (p=0) : {   'fun': 0.7499999984147923,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=1) : {   'fun': 0.7403926353927567,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=2) : {   'fun': 0.7119397637595464,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=3) : {   'fun': 0.6657348042885504,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=4) : {   'fun': 0.6035533854230306,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=5) : {   'fun': 0.5277851106134874,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=6) : {   'fun': 0.4413417152855485,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=7) : {   'fun': 0.3475451522406212,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=8) : {   'fun': 0.24999999117937668,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=9) : {   'fun': 0.15245483451406922,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=10) : {   'fun': 0.0586582820420945,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=11) : {   'fun': -0.02778511798523725,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=12) : {   'fun': -0.1035533914817795,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=13) : {   'fun': -0.16573480855815326,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=14) : {   'fun': -0.2119397677203292,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=15) : {   'fun': -0.24039264317732695,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=16) : {   'fun': -0.25000000222200414,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=17) : {   'fun': -0.24039264186908968,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=18) : {   'fun': -0.21193977093691563,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=19) : {   'fun': -0.1657348118410386,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=20) : {   'fun': -0.1035533929932122,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=21) : {   'fun': -0.02778511966266356,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=22) : {   'fun': 0.058658275334834,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=23) : {   'fun': 0.15245483699669812,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=24) : {   'fun': 0.24999999432658457,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=25) : {   'fun': 0.3475451589736517,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=26) : {   'fun': 0.441341709547203,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=27) : {   'fun': 0.527785113715725,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=28) : {   'fun': 0.6035533835906788,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=29) : {   'fun': 0.665734803343436,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=30) : {   'fun': 0.7119397648018393,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
# 1th eigen energy information (p=31) : {   'fun': 0.7403926394225672,
#     'jac': None,
#     'nfev': 1,
#     'nit': None,
#     'njev': None,
#     'x': array([], dtype=float64)}
